# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"UTC\"")

# %%
hex_project_id = _hex_json.loads("\"24373d7b-4167-48e2-a2ee-2a91de5fd677\"")

# %%
import numpy as np
import pandas as pd

# %%
col_names = ["airline","airline_num","source_name","source_num","dest_name","dest_num","None","stop_count","equipment"]

# %%
df = pd.read_csv('routes.csv', header=0, names = col_names)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>airline</th>
#       <th>airline_num</th>
#       <th>source_name</th>
#       <th>source_num</th>
#       <th>dest_name</th>
#       <th>dest_num</th>
#       <th>None</th>
#       <th>stop_count</th>
#       <th>equipment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2B</td>
#       <td>410</td>
#       <td>ASF</td>
#       <td>2966</td>
#       <td>KZN</td>
#       <td>2990</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>CR2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2B</td>
#       <td>410</td>
#       <td>ASF</td>
#       <td>2966</td>
# ...

# %%
routes_cleaned = df.drop(["airline","airline_num","source_num","dest_num","None","stop_count","equipment"], axis = 1)
routes_cleaned.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>source_name</th>
#       <th>dest_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ASF</td>
#       <td>KZN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ASF</td>
#       <td>MRV</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CEK</td>
#       <td>KZN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>CEK</td>
#       <td>OVB</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>DME</td>
#       <td>KZN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
routes_cleaned.to_csv('routes_cleaned.csv', index = False, header = False)
